# %%
# Importing the required library
import pandas as pd

# Reading the Excel file into a Pandas DataFrame
df = pd.read_excel('Data_BA.xlsx')

# Displaying the first 5 rows of the DataFrame to verify that the data has been read correctly
df.head()
# Out:
#                              Område  \
# 0                 BBU City-Østerbro
# 1                 BBU City-Østerbro
# 2                 BBU City-Østerbro
# 3   BBU Valby-Vesterbro-Kgs.Enghave
# 4  BBU AF Økonomi og Digitalisering
#
#                                                 Team  Indsatslængde  \
# 0                BBU City-Østerbro - MY Børnegruppen             90
# 1                BBU City-Østerbro - MY Børnegruppen            161
# 2                BBU City-Østerbro - MY Børnegruppen              0
# 3  BBU Valby-Vesterbro-Kgs.Enghave - Styrket modt...            239
# 4                                                NaN            123
#
#                   Indsats                                    Indsatsparagraf  \
# 0       Familiebehandling     SEL § 52, stk. 3, nr. 3 (fx familiebehandling)
# 1       Familiebehandling     SEL § 52, stk. 3, nr. 3 (fx familiebehandling)
# 2       Familiebehandling     SEL § 52, stk. 3, nr. 3 (fx familiebehandling)
# ...

# %%
# Remove rows where 'latest_enddate' or 'PrisIAlt' are missing
df_cleaned = df.dropna(subset=['sag_slut', 'PrisIAlt'])

# Check the shape of the DataFrame before and after cleaning to see how many rows were removed
rows_before = df.shape[0]
rows_after = df_cleaned.shape[0]
rows_removed = rows_before - rows_after

rows_before, rows_after, rows_removed
# Out:
# (1015, 651, 364)

# %% [markdown]
# ## Datavisualisering

# %% [markdown]
# ## Regressioner
