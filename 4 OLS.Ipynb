# %%
# Importing the required library
import pandas as pd

# Reading the Excel file into a Pandas DataFrame
df = pd.read_excel('Data/Data_BA_modified.xlsx')

# Displaying the first 5 rows of the DataFrame to verify that the data has been read correctly
df
# Out:
#                                                   Team  Indsatslængde  \
# 0                  BBU City-Østerbro - MY Børnegruppen             90
# 1                  BBU City-Østerbro - MY Børnegruppen            161
# 2                  BBU City-Østerbro - MY Børnegruppen              0
# 3    BBU Valby-Vesterbro-Kgs.Enghave - Styrket modt...            239
# 4                                                  NaN            123
# ..                                                 ...            ...
# 646         BBU Valby-Vesterbro-Kgs.Enghave - Børneliv            134
# 647         BBU Valby-Vesterbro-Kgs.Enghave - Børneliv            182
# 648         BBU Valby-Vesterbro-Kgs.Enghave - Børneliv            112
# 649         BBU Valby-Vesterbro-Kgs.Enghave - Børneliv            899
# 650  BBU Nørrebro-Bispebjerg - Distrikt Guldberg-Bl...            389
#
#      PrisIAlt  alder  alder_ved_hændelse  status  personID_serial  \
# 0       28091      6                   3  lukket              629
# 1       47375      2                   0  lukket              604
# 2          39      1                   0  lukket               34
# 3      141911      2                   0  lukket              167
# 4       49000      5                   3  lukket              671
# ..        ...    ...                 ...     ...              ...
# 646     14880      7                   4  lukket              420
# 647     61639      5                   5  lukket              316
# 648     36903      6                   2  lukket              446
# 649    101450      7                   3  lukket              254
# 650    137600      8                   5  lukket              560
#
#      caseworker_serial  sag_varighed  Indsats_Familiebehandling  ...  \
# 0                    1           507                          1  ...
# 1                    1           811                          1  ...
# 2                    1           848                          1  ...
# 3                    2           593                          1  ...
# 4                    3           756                          0  ...
# ..                 ...           ...                        ...  ...
# 646                296           456                          1  ...
# 647                296           140                          1  ...
# 648                296          1141                          1  ...
# 649                296          1195                          1  ...
# 650                297          1741                          1  ...
#
#      BaggrundBarnet_BaggrundBarnet_Anden form for omsorgssvigt over for barn/ung  \
# 0                                                    0
# 1                                                    0
# 2                                                    1
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 646                                                  0
# 647                                                  0
# 648                                                  0
# 649                                                  0
# 650                                                  0
#
#      BaggrundBarnet_BaggrundBarnet_Betydelig eller varigt nedsat fysisk eller psykisk funktionsevne hos barn/ung  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 646                                                  0
# 647                                                  0
# 648                                                  0
# 649                                                  0
# 650                                                  0
#
#      BaggrundBarnet_BaggrundBarnet_Overgreb mod barn/ung f.eks. seksuelt eller voldeligt  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 646                                                  0
# 647                                                  0
# 648                                                  0
# 649                                                  0
# 650                                                  0
#
#      BaggrundHjemmet_BaggrundHjemmet_Anden bekymrende adfærd hos forældre  \
# 0                                                    0
# 1                                                    0
# 2                                                    1
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 646                                                  0
# 647                                                  0
# 648                                                  0
# 649                                                  0
# 650                                                  0
#
#      BaggrundHjemmet_BaggrundHjemmet_Betydelig eller varigt nedsat fysisk eller psykisk funktionsevne hos forældre  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 646                                                  0
# 647                                                  0
# 648                                                  0
# 649                                                  0
# 650                                                  0
#
#      BaggrundHjemmet_BaggrundHjemmet_Højt konfliktniveau eller vold i hjemmet mellem voksne  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 646                                                  0
# 647                                                  0
# 648                                                  0
# 649                                                  0
# 650                                                  0
#
#      BaggrundHjemmet_BaggrundHjemmet_Misbrug hos forældre  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    1
# 4                                                    0
# ..                                                 ...
# 646                                                  0
# 647                                                  0
# 648                                                  0
# 649                                                  0
# 650                                                  0
#
#      Underretter_Anden_Kommune  Underretter_Sundhedsvæsen  \
# 0                            0                          0
# 1                            1                          0
# 2                            0                          1
# 3                            0                          0
# 4                            0                          0
# ..                         ...                        ...
# 646                          0                          0
# 647                          0                          0
# 648                          0                          0
# 649                          0                          0
# 650                          0                          0
#
#      Underretter_Socialrådgiver
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ..                          ...
# 646                           0
# 647                           0
# 648                           0
# 649                           0
# 650                           0
#
# [651 rows x 67 columns]

# %%
import statsmodels.api as sm

# Prepare the results dictionary to store regression summaries
results = {}

# 1. Simple regression with sag_varighed as Y and PrisIAlt as X
X1 = sm.add_constant(df['PrisIAlt'])
y = df['sag_varighed']
model1 = sm.OLS(y, X1).fit()
results['model1'] = model1.summary()

# 2. Simple regression with sag_varighed as Y and alder_ved_hændelse as X
X2 = sm.add_constant(df['alder_ved_hændelse'])
model2 = sm.OLS(y, X2).fit()
results['model2'] = model2.summary()

# 3. sag_varighed as Y, PrisIAlt as beta1 and alder_ved_hændelse as control
X3 = sm.add_constant(df[['PrisIAlt', 'alder_ved_hændelse']])
model3 = sm.OLS(y, X3).fit()
results['model3'] = model3.summary()

prefixes = ['Underretter', 'BaggrundBarnet', 'BaggrundHjemmet', 'Område']
prefix_columns = {prefix: [col for col in df.columns if col.startswith(prefix)] for prefix in prefixes}


# 4. sag_varighed as Y, PrisIAlt as beta1, and the following controls: alder_ved_hændelse, and columns with prefixes
control_vars = ['alder_ved_hændelse'] + ['Indsatslængde'] + [col for prefix in prefixes for col in prefix_columns[prefix]]
X4 = sm.add_constant(df[['PrisIAlt'] + control_vars])
model4 = sm.OLS(y, X4).fit()
results['model4'] = model4.summary()

# Display the summary statistics for each model
results
# Out:
# {'model1': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:           sag_varighed   R-squared:                       0.000
#  Model:                            OLS   Adj. R-squared:                 -0.001
#  Method:                 Least Squares   F-statistic:                    0.2877
#  Date:                Mon, 23 Oct 2023   Prob (F-statistic):              0.592
#  Time:                        19:12:17   Log-Likelihood:                -4906.4
#  No. Observations:                 651   AIC:                             9817.
#  Df Residuals:                     649   BIC:                             9826.
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const        546.6001     21.983     24.865      0.000     503.434     589.766
#  PrisIAlt    8.531e-05      0.000      0.536      0.592      -0.000       0.000
#  ==============================================================================
#  Omnibus:                      224.090   Durbin-Watson:                   1.594
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              912.450
#  Skew:                           1.549   Prob(JB):                    7.31e-199
#  Kurtosis:                       7.904   Cond. No.                     1.71e+05
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  [2] The condition number is large, 1.71e+05. This might indicate that there are
#  strong multicollinearity or other numerical problems.
#  """,
#  'model2': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:           sag_varighed   R-squared:                       0.010
#  Model:                            OLS   Adj. R-squared:                  0.009
#  Method:                 Least Squares   F-statistic:                     6.638
#  Date:                Mon, 23 Oct 2023   Prob (F-statistic):             0.0102
#  Time:                        19:12:17   Log-Likelihood:                -4903.3
#  No. Observations:                 651   AIC:                             9811.
#  Df Residuals:                     649   BIC:                             9819.
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
#  --------------------------------------------------------------------------------------
#  const                491.6555     29.844     16.474      0.000     433.053     550.258
#  alder_ved_hændelse    24.4923      9.506      2.576      0.010       5.825      43.159
#  ==============================================================================
#  Omnibus:                      216.949   Durbin-Watson:                   1.601
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              861.960
#  Skew:                           1.503   Prob(JB):                    6.73e-188
#  Kurtosis:                       7.768   Cond. No.                         5.64
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'model3': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:           sag_varighed   R-squared:                       0.010
#  Model:                            OLS   Adj. R-squared:                  0.007
#  Method:                 Least Squares   F-statistic:                     3.418
#  Date:                Mon, 23 Oct 2023   Prob (F-statistic):             0.0334
#  Time:                        19:12:17   Log-Likelihood:                -4903.1
#  No. Observations:                 651   AIC:                             9812.
#  Df Residuals:                     648   BIC:                             9826.
#  Df Model:                           2
#  Covariance Type:            nonrobust
#  ======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
#  --------------------------------------------------------------------------------------
#  const                486.1726     32.201     15.098      0.000     422.942     549.403
#  PrisIAlt            7.211e-05      0.000      0.455      0.649      -0.000       0.000
#  alder_ved_hændelse    24.3514      9.517      2.559      0.011       5.663      43.040
#  ==============================================================================
#  Omnibus:                      216.409   Durbin-Watson:                   1.599
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              862.633
#  Skew:                           1.498   Prob(JB):                    4.80e-188
#  Kurtosis:                       7.778   Cond. No.                     2.57e+05
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  [2] The condition number is large, 2.57e+05. This might indicate that there are
#  strong multicollinearity or other numerical problems.
#  """,
#  'model4': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:           sag_varighed   R-squared:                       0.161
#  Model:                            OLS   Adj. R-squared:                  0.085
#  Method:                 Least Squares   F-statistic:                     2.123
#  Date:                Mon, 23 Oct 2023   Prob (F-statistic):           1.27e-05
#  Time:                        19:12:17   Log-Likelihood:                -4849.3
#  No. Observations:                 651   AIC:                             9809.
#  Df Residuals:                     596   BIC:                         1.005e+04
#  Df Model:                          54
#  Covariance Type:            nonrobust
#  ========================================================================================================================================================================================
#                                                                                                                             coef    std err          t      P>|t|      [0.025      0.975]
#  ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  const                                                                                                                  539.4914     87.074      6.196      0.000     368.481     710.501
#  PrisIAlt                                                                                                             -8.671e-05      0.000     -0.494      0.621      -0.000       0.000
#  alder_ved_hændelse                                                                                                      19.1466     11.127      1.721      0.086      -2.706      41.000
#  Indsatslængde                                                                                                            0.3112      0.106      2.937      0.003       0.103       0.519
#  Underretter_(Ingen)                                                                                                    627.6132    299.643      2.095      0.037      39.129    1216.098
#  Underretter_Anbringelsessted                                                                                            13.6650    298.448      0.046      0.963    -572.473     599.803
#  Underretter_Anden offentlig myndighed                                                                                   25.8452     91.274      0.283      0.777    -153.413     205.103
#  Underretter_Anonym                                                                                                    -111.7671     80.320     -1.392      0.165    -269.511      45.977
#  Underretter_Barnets netværk                                                                                            162.2956    176.683      0.919      0.359    -184.701     509.292
#  Underretter_Daginstitution/Dagpleje                                                                                    -74.7213     56.347     -1.326      0.185    -185.384      35.941
#  Underretter_Familie                                                                                                    338.8843    136.527      2.482      0.013      70.751     607.017
#  Underretter_Familiens bekendtskabskreds                                                                               -149.9100    300.869     -0.498      0.618    -740.803     440.983
#  Underretter_Forældremyndighedsindehaver                                                                                  0.2614     91.654      0.003      0.998    -179.742     180.265
#  Underretter_Krisecenter                                                                                                 56.5430     79.443      0.712      0.477     -99.480     212.566
#  Underretter_Naboer                                                                                                     100.6469    194.517      0.517      0.605    -281.376     482.670
#  Underretter_Politi                                                                                                    -114.9188     78.278     -1.468      0.143    -268.653      38.816
#  Underretter_Psykiatri                                                                                                  -40.8463     91.869     -0.445      0.657    -221.273     139.580
#  Underretter_Psykolog                                                                                                  -244.2352    440.049     -0.555      0.579   -1108.471     620.001
#  Underretter_SFO/Fritidshjem/Klub                                                                                        19.4413    260.195      0.075      0.940    -491.569     530.452
#  Underretter_Skole                                                                                                      -51.8540    102.802     -0.504      0.614    -253.753     150.045
#  Underretter_Øvrige                                                                                                      96.8451     69.413      1.395      0.163     -39.479     233.169
#  Underretter_Anden_Kommune                                                                                              -58.2976     70.016     -0.833      0.405    -195.806      79.211
#  Underretter_Sundhedsvæsen                                                                                              -73.2426     62.380     -1.174      0.241    -195.754      49.269
#  Underretter_Socialrådgiver                                                                                              17.2433    135.176      0.128      0.899    -248.236     282.723
#  BaggrundBarnet_Anden bekymrende adfærd hos barn/ung fx udadreagerende adfærd                                          -132.8300     63.709     -2.085      0.037    -257.951      -7.709
#  BaggrundBarnet_Anden form for omsorgssvigt over for barn/ung                                                           137.1906     59.094      2.322      0.021      21.133     253.248
#  BaggrundBarnet_Betydelig eller varigt nedsat fysisk eller psykisk funktionsevne hos barn/ung                          -183.6176    153.644     -1.195      0.233    -485.366     118.131
#  BaggrundBarnet_Overgreb mod barn/ung f.eks. seksuelt eller voldeligt                                                   -38.4334     61.838     -0.622      0.534    -159.879      83.013
#  BaggrundBarnet_Overgreb mod barn/ung f.eks. seksuelt eller voldeligt, begået af andre end barnets/den unges forældre  -557.4451    320.229     -1.741      0.082   -1186.359      71.469
#  BaggrundBarnet_Sundhedsforhold hos barn/ung                                                                            -94.6263     95.966     -0.986      0.325    -283.099      93.847
#  BaggrundBarnet_BaggrundBarnet_Anden bekymrende adfærd hos barn/ung fx udadreagerende adfærd                            -84.8843    129.255     -0.657      0.512    -338.736     168.967
#  BaggrundBarnet_Skoleproblemer hos barn/ung fx fravær                                                                  -786.5766    456.327     -1.724      0.085   -1682.781     109.628
#  BaggrundBarnet_BaggrundBarnet_Anden form for omsorgssvigt over for barn/ung                                            286.9349    140.983      2.035      0.042      10.052     563.818
#  BaggrundBarnet_BaggrundBarnet_Betydelig eller varigt nedsat fysisk eller psykisk funktionsevne hos barn/ung            184.6105    457.998      0.403      0.687    -714.875    1084.096
#  BaggrundBarnet_BaggrundBarnet_Overgreb mod barn/ung f.eks. seksuelt eller voldeligt                                   -186.1628    450.272     -0.413      0.679   -1070.475     698.149
#  BaggrundHjemmet_Anden bekymrende adfærd hos forældre                                                                   -56.9358     52.963     -1.075      0.283    -160.952      47.080
#  BaggrundHjemmet_Betydelig eller varigt nedsat fysisk eller psykisk funktionsevne hos forældre                          -65.8851     73.126     -0.901      0.368    -209.501      77.731
#  BaggrundHjemmet_Fogedsag, hjemløshed eller udsættelse fra bolig                                                       -243.0101    102.516     -2.370      0.018    -444.347     -41.673
#  BaggrundHjemmet_Højt konfliktniveau eller vold i hjemmet mellem voksne                                                 -34.1428     55.980     -0.610      0.542    -144.086      75.800
#  BaggrundHjemmet_Kriminalitet hos forældre                                                                             -116.6395    210.186     -0.555      0.579    -529.435     296.156
#  BaggrundHjemmet_Misbrug hos forældre                                                                                  -125.8834     71.120     -1.770      0.077    -265.561      13.794
#  BaggrundHjemmet_Overgreb mod barn/ung, f.eks. seksuelt eller voldeligt, begået af forældrene                          -463.4250    179.319     -2.584      0.010    -815.600    -111.250
#  BaggrundHjemmet_Sundhedsforhold hos en eller begge forældre                                                           -471.4284    445.167     -1.059      0.290   -1345.716     402.859
#  BaggrundHjemmet_Utilstrækkelig omsorg fra forældre                                                                    -130.7360     69.284     -1.887      0.060    -266.807       5.335
#  BaggrundHjemmet_BaggrundHjemmet_Anden bekymrende adfærd hos forældre                                                   -63.3220     77.196     -0.820      0.412    -214.931      88.287
#  BaggrundHjemmet_BaggrundHjemmet_Betydelig eller varigt nedsat fysisk eller psykisk funktionsevne hos forældre          -23.5712     97.553     -0.242      0.809    -215.160     168.018
#  BaggrundHjemmet_BaggrundHjemmet_Højt konfliktniveau eller vold i hjemmet mellem voksne                                  10.7839    124.856      0.086      0.931    -234.427     255.995
#  BaggrundHjemmet_BaggrundHjemmet_Misbrug hos forældre                                                                  -227.1117    231.601     -0.981      0.327    -681.966     227.743
#  Område_BBU AF Økonomi og Digitalisering                                                                                305.8395    403.505      0.758      0.449    -486.625    1098.304
#  Område_BBU Amager                                                                                                       89.7113     75.792      1.184      0.237     -59.141     238.564
#  Område_BBU Brønshøj-Husum-Vanløse                                                                                       49.5177     80.790      0.613      0.540    -109.149     208.185
#  Område_BBU City-Østerbro                                                                                               -55.5654     87.477     -0.635      0.526    -227.366     116.235
#  Område_BBU Flygtningeindsats                                                                                           -61.7001    202.083     -0.305      0.760    -458.582     335.182
#  Område_BBU Nørrebro-Bispebjerg                                                                                           6.3412     74.145      0.086      0.932    -139.276     151.959
#  Område_BBU Valby-Vesterbro-Kgs.Enghave                                                                                 -15.9658     76.611     -0.208      0.835    -166.426     134.494
#  Område_BCH Børneområdet                                                                                               -196.3712    111.411     -1.763      0.078    -415.177      22.435
#  Område_Teamet for koordineret indsats (KIT)                                                                            417.6840    401.511      1.040      0.299    -370.864    1206.232
#  ==============================================================================
#  Omnibus:                      195.018   Durbin-Watson:                   1.671
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              748.883
#  Skew:                           1.350   Prob(JB):                    2.41e-163
#  Kurtosis:                       7.507   Cond. No.                     2.02e+17
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  [2] The smallest eigenvalue is 3.05e-22. This might indicate that there are
#  strong multicollinearity problems or that the design matrix is singular.
#  """}

# %%
# Initialize LaTeX table
latex_table = "\\begin{table}\n"
latex_table += "\\caption{OLS modified}\n"
latex_table += "\\label{}\n"
latex_table += "\\begin{center}\n"
latex_table += "\\begin{tabular}{lllll}\n"
latex_table += "\\hline\n"
latex_table += " & Model 1 & Model 2 & Model 3 & Model 4 \\\\\n"
latex_table += "\\hline\n"

# Define variables and statistics of interest
variables = ['const', 'PrisIAlt', 'alder_ved_hændelse', 'Indsatslængde']
statistics = ['R-squared', 'R-squared Adj.', 'F-statistic']

# Add coefficients and standard errors for each variable
for var in variables:
    latex_table += f"{var} & "
    for model_name in ['model1', 'model2', 'model3', 'model4']:
        model = results[model_name]
        if var in model.params.index:
            coef = model.params[var]
            latex_table += f"{coef:.4f} & "
        else:
            latex_table += " & "
    latex_table = latex_table.rstrip(" & ")
    latex_table += " \\\\\n"
    latex_table += " & "
    for model_name in ['model1', 'model2', 'model3', 'model4']:
        model = results[model_name]
        if var in model.bse.index:
            std_err = model.bse[var]
            latex_table += f"({std_err:.4f}) & "
        else:
            latex_table += " & "
    latex_table = latex_table.rstrip(" & ")
    latex_table += " \\\\\n"

# Add statistics
for stat in statistics:
    latex_table += f"{stat} & "
    for model_name in ['model1', 'model2', 'model3', 'model4']:
        model = results[model_name]
        if stat == 'R-squared':
            value = model.rsquared
        elif stat == 'R-squared Adj.':
            value = model.rsquared_adj
        elif stat == 'F-statistic':
            value = model.fvalue
        latex_table += f"{value:.4f} & "
    latex_table = latex_table.rstrip(" & ")
    latex_table += " \\\\\n"

# Close LaTeX table
latex_table += "\\hline\n"
latex_table += "\\end{tabular}\n"
latex_table += "\\end{center}\n"
latex_table += "\\end{table}"

# Print the LaTeX table
print(latex_table)
# Out:
# \begin{table}
# \caption{OLS modified}
# \label{}
# \begin{center}
# \begin{tabular}{lllll}
# \hline
#  & Model 1 & Model 2 & Model 3 & Model 4 \\
# \hline
# const & 546.6001 & 491.6555 & 486.1726 & 539.4914 \\
#  & (21.9826) & (29.8438) & (32.2008) & (87.0744) \\
# PrisIAlt & 0.0001 &  & 0.0001 & -0.0001 \\
#  & (0.0002) &  & (0.0002) & (0.0002) \\
# alder_ved_hændelse &  & 24.4923 & 24.3514 & 19.1466 \\
#  &  & (9.5063) & (9.5172) & (11.1270) \\
# Indsatslængde &  &  &  & 0.3112 \\
#  &  &  &  & (0.1060) \\
# R-squared & 0.0004 & 0.0101 & 0.0104 & 0.1613 \\
# R-squared Adj. & -0.0011 & 0.0086 & 0.0074 & 0.0853 \\
# F-statistic & 0.2877 & 6.6379 & 3.4185 & 2.1226 \\
# \hline
# \end{tabular}
# \end{center}
# \end{table}
