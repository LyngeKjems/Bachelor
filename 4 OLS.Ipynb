# %%
# Importing the required library
import pandas as pd

# Reading the Excel file into a Pandas DataFrame
df = pd.read_excel('Data/Data_BA_modified.xlsx')

# Displaying the first 5 rows of the DataFrame to verify that the data has been read correctly
df
# Out:
#                                                   Team  Indsatslængde  \
# 0                  BBU City-Østerbro - MY Børnegruppen             90
# 1                  BBU City-Østerbro - MY Børnegruppen            161
# 2                  BBU City-Østerbro - MY Børnegruppen              0
# 3    BBU Valby-Vesterbro-Kgs.Enghave - Styrket modt...            239
# 4                                                  NaN            123
# ..                                                 ...            ...
# 646         BBU Valby-Vesterbro-Kgs.Enghave - Børneliv            134
# 647         BBU Valby-Vesterbro-Kgs.Enghave - Børneliv            182
# 648         BBU Valby-Vesterbro-Kgs.Enghave - Børneliv            112
# 649         BBU Valby-Vesterbro-Kgs.Enghave - Børneliv            899
# 650  BBU Nørrebro-Bispebjerg - Distrikt Guldberg-Bl...            389
#
#      PrisIAlt  alder  alder_ved_hændelse  status  personID_serial  \
# 0       28091      6                   3  lukket              629
# 1       47375      2                   0  lukket              604
# 2          39      1                   0  lukket               34
# 3      141911      2                   0  lukket              167
# 4       49000      5                   3  lukket              671
# ..        ...    ...                 ...     ...              ...
# 646     14880      7                   4  lukket              420
# 647     61639      5                   5  lukket              316
# 648     36903      6                   2  lukket              446
# 649    101450      7                   3  lukket              254
# 650    137600      8                   5  lukket              560
#
#      caseworker_serial  sag_varighed  Indsats_Familiebehandling  ...  \
# 0                    1           507                          1  ...
# 1                    1           811                          1  ...
# 2                    1           848                          1  ...
# 3                    2           593                          1  ...
# 4                    3           756                          0  ...
# ..                 ...           ...                        ...  ...
# 646                296           456                          1  ...
# 647                296           140                          1  ...
# 648                296          1141                          1  ...
# 649                296          1195                          1  ...
# 650                297          1741                          1  ...
#
#      BaggrundBarnet_BaggrundBarnet_Anden form for omsorgssvigt over for barn/ung  \
# 0                                                    0
# 1                                                    0
# 2                                                    1
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 646                                                  0
# 647                                                  0
# 648                                                  0
# 649                                                  0
# 650                                                  0
#
#      BaggrundBarnet_BaggrundBarnet_Betydelig eller varigt nedsat fysisk eller psykisk funktionsevne hos barn/ung  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 646                                                  0
# 647                                                  0
# 648                                                  0
# 649                                                  0
# 650                                                  0
#
#      BaggrundBarnet_BaggrundBarnet_Overgreb mod barn/ung f.eks. seksuelt eller voldeligt  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 646                                                  0
# 647                                                  0
# 648                                                  0
# 649                                                  0
# 650                                                  0
#
#      BaggrundHjemmet_BaggrundHjemmet_Anden bekymrende adfærd hos forældre  \
# 0                                                    0
# 1                                                    0
# 2                                                    1
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 646                                                  0
# 647                                                  0
# 648                                                  0
# 649                                                  0
# 650                                                  0
#
#      BaggrundHjemmet_BaggrundHjemmet_Betydelig eller varigt nedsat fysisk eller psykisk funktionsevne hos forældre  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 646                                                  0
# 647                                                  0
# 648                                                  0
# 649                                                  0
# 650                                                  0
#
#      BaggrundHjemmet_BaggrundHjemmet_Højt konfliktniveau eller vold i hjemmet mellem voksne  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 646                                                  0
# 647                                                  0
# 648                                                  0
# 649                                                  0
# 650                                                  0
#
#      BaggrundHjemmet_BaggrundHjemmet_Misbrug hos forældre  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    1
# 4                                                    0
# ..                                                 ...
# 646                                                  0
# 647                                                  0
# 648                                                  0
# 649                                                  0
# 650                                                  0
#
#      Underretter_Anden_Kommune  Underretter_Sundhedsvæsen  \
# 0                            0                          0
# 1                            1                          0
# 2                            0                          1
# 3                            0                          0
# 4                            0                          0
# ..                         ...                        ...
# 646                          0                          0
# 647                          0                          0
# 648                          0                          0
# 649                          0                          0
# 650                          0                          0
#
#      Underretter_Socialrådgiver
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ..                          ...
# 646                           0
# 647                           0
# 648                           0
# 649                           0
# 650                           0
#
# [651 rows x 67 columns]

# %%
import statsmodels.api as sm

# Prepare the results dictionary to store regression summaries
results = {}

# 1. Simple regression with sag_varighed as Y and PrisIAlt as X
X1 = sm.add_constant(df['PrisIAlt'])
y = df['sag_varighed']
model1 = sm.OLS(y, X1).fit()
results['model1'] = model1.summary()

# 2. Simple regression with sag_varighed as Y and alder_ved_hændelse as X
X2 = sm.add_constant(df['alder_ved_hændelse'])
model2 = sm.OLS(y, X2).fit()
results['model2'] = model2.summary()

# 3. sag_varighed as Y, PrisIAlt as beta1 and alder_ved_hændelse as control
X3 = sm.add_constant(df[['PrisIAlt', 'alder_ved_hændelse']])
model3 = sm.OLS(y, X3).fit()
results['model3'] = model3.summary()

prefixes = ['Underretter', 'BaggrundBarnet', 'BaggrundHjemmet', 'Område']
prefix_columns = {prefix: [col for col in df.columns if col.startswith(prefix)] for prefix in prefixes}


# 4. sag_varighed as Y, PrisIAlt as beta1, and the following controls: alder_ved_hændelse, and columns with prefixes
control_vars = ['alder_ved_hændelse'] + [col for prefix in prefixes for col in prefix_columns[prefix]]
X4 = sm.add_constant(df[['PrisIAlt'] + control_vars])
model4 = sm.OLS(y, X4).fit()
results['model4'] = model4.summary()

# Display the summary statistics for each model
results
# Out:
# {'model1': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:           sag_varighed   R-squared:                       0.000
#  Model:                            OLS   Adj. R-squared:                 -0.001
#  Method:                 Least Squares   F-statistic:                    0.2877
#  Date:                Fri, 20 Oct 2023   Prob (F-statistic):              0.592
#  Time:                        15:03:58   Log-Likelihood:                -4906.4
#  No. Observations:                 651   AIC:                             9817.
#  Df Residuals:                     649   BIC:                             9826.
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ==============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
#  const        546.6001     21.983     24.865      0.000     503.434     589.766
#  PrisIAlt    8.531e-05      0.000      0.536      0.592      -0.000       0.000
#  ==============================================================================
#  Omnibus:                      224.090   Durbin-Watson:                   1.594
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              912.450
#  Skew:                           1.549   Prob(JB):                    7.31e-199
#  Kurtosis:                       7.904   Cond. No.                     1.71e+05
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  [2] The condition number is large, 1.71e+05. This might indicate that there are
#  strong multicollinearity or other numerical problems.
#  """,
#  'model2': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:           sag_varighed   R-squared:                       0.010
#  Model:                            OLS   Adj. R-squared:                  0.009
#  Method:                 Least Squares   F-statistic:                     6.638
#  Date:                Fri, 20 Oct 2023   Prob (F-statistic):             0.0102
#  Time:                        15:03:58   Log-Likelihood:                -4903.3
#  No. Observations:                 651   AIC:                             9811.
#  Df Residuals:                     649   BIC:                             9819.
#  Df Model:                           1
#  Covariance Type:            nonrobust
#  ======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
#  --------------------------------------------------------------------------------------
#  const                491.6555     29.844     16.474      0.000     433.053     550.258
#  alder_ved_hændelse    24.4923      9.506      2.576      0.010       5.825      43.159
#  ==============================================================================
#  Omnibus:                      216.949   Durbin-Watson:                   1.601
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              861.960
#  Skew:                           1.503   Prob(JB):                    6.73e-188
#  Kurtosis:                       7.768   Cond. No.                         5.64
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  """,
#  'model3': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:           sag_varighed   R-squared:                       0.010
#  Model:                            OLS   Adj. R-squared:                  0.007
#  Method:                 Least Squares   F-statistic:                     3.418
#  Date:                Fri, 20 Oct 2023   Prob (F-statistic):             0.0334
#  Time:                        15:03:58   Log-Likelihood:                -4903.1
#  No. Observations:                 651   AIC:                             9812.
#  Df Residuals:                     648   BIC:                             9826.
#  Df Model:                           2
#  Covariance Type:            nonrobust
#  ======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
#  --------------------------------------------------------------------------------------
#  const                486.1726     32.201     15.098      0.000     422.942     549.403
#  PrisIAlt            7.211e-05      0.000      0.455      0.649      -0.000       0.000
#  alder_ved_hændelse    24.3514      9.517      2.559      0.011       5.663      43.040
#  ==============================================================================
#  Omnibus:                      216.409   Durbin-Watson:                   1.599
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              862.633
#  Skew:                           1.498   Prob(JB):                    4.80e-188
#  Kurtosis:                       7.778   Cond. No.                     2.57e+05
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  [2] The condition number is large, 2.57e+05. This might indicate that there are
#  strong multicollinearity or other numerical problems.
#  """,
#  'model4': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
#  ==============================================================================
#  Dep. Variable:           sag_varighed   R-squared:                       0.149
#  Model:                            OLS   Adj. R-squared:                  0.074
#  Method:                 Least Squares   F-statistic:                     1.975
#  Date:                Fri, 20 Oct 2023   Prob (F-statistic):           9.03e-05
#  Time:                        15:03:58   Log-Likelihood:                -4854.0
#  No. Observations:                 651   AIC:                             9816.
#  Df Residuals:                     597   BIC:                         1.006e+04
#  Df Model:                          53
#  Covariance Type:            nonrobust
#  ========================================================================================================================================================================================
#                                                                                                                             coef    std err          t      P>|t|      [0.025      0.975]
#  ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  const                                                                                                                  598.6519     85.252      7.022      0.000     431.222     766.082
#  PrisIAlt                                                                                                                 0.0001      0.000      0.771      0.441      -0.000       0.000
#  alder_ved_hændelse                                                                                                      22.9511     11.122      2.064      0.039       1.109      44.794
#  Underretter_(Ingen)                                                                                                    651.1395    301.443      2.160      0.031      59.122    1243.157
#  Underretter_Anbringelsessted                                                                                            59.7036    299.934      0.199      0.842    -529.350     648.757
#  Underretter_Anden offentlig myndighed                                                                                   17.9010     91.815      0.195      0.845    -162.419     198.221
#  Underretter_Anonym                                                                                                    -113.8052     80.828     -1.408      0.160    -272.547      44.936
#  Underretter_Barnets netværk                                                                                            163.2201    177.807      0.918      0.359    -185.983     512.424
#  Underretter_Daginstitution/Dagpleje                                                                                    -86.6657     56.558     -1.532      0.126    -197.742      24.411
#  Underretter_Familie                                                                                                    330.5307    137.367      2.406      0.016      60.750     600.311
#  Underretter_Familiens bekendtskabskreds                                                                               -147.9943    302.784     -0.489      0.625    -742.645     446.657
#  Underretter_Forældremyndighedsindehaver                                                                                  2.3553     92.235      0.026      0.980    -178.788     183.499
#  Underretter_Krisecenter                                                                                                 51.9410     79.933      0.650      0.516    -105.044     208.926
#  BaggrundHjemmet_Fogedsag, hjemløshed eller udsættelse fra bolig                                                       -286.3858    102.093     -2.805      0.005    -486.890     -85.881
#  BaggrundHjemmet_Højt konfliktniveau eller vold i hjemmet mellem voksne                                                 -45.8152     56.195     -0.815      0.415    -156.178      64.548
#  BaggrundHjemmet_Kriminalitet hos forældre                                                                             -113.3798    211.521     -0.536      0.592    -528.796     302.037
#  BaggrundHjemmet_Misbrug hos forældre                                                                                  -127.9005     71.570     -1.787      0.074    -268.460      12.659
#  BaggrundHjemmet_Overgreb mod barn/ung, f.eks. seksuelt eller voldeligt, begået af forældrene                          -500.6628    180.009     -2.781      0.006    -854.191    -147.134
#  BaggrundHjemmet_Sundhedsforhold hos en eller begge forældre                                                           -444.8247    447.909     -0.993      0.321   -1324.493     434.844
#  BaggrundHjemmet_Utilstrækkelig omsorg fra forældre                                                                    -122.2417     69.665     -1.755      0.080    -259.059      14.576
#  BaggrundHjemmet_BaggrundHjemmet_Anden bekymrende adfærd hos forældre                                                   -72.0911     77.629     -0.929      0.353    -224.551      80.369
#  BaggrundHjemmet_BaggrundHjemmet_Betydelig eller varigt nedsat fysisk eller psykisk funktionsevne hos forældre          -17.9453     98.155     -0.183      0.855    -210.716     174.826
#  BaggrundHjemmet_BaggrundHjemmet_Højt konfliktniveau eller vold i hjemmet mellem voksne                                 -13.9255    125.365     -0.111      0.912    -260.136     232.285
#  BaggrundHjemmet_BaggrundHjemmet_Misbrug hos forældre                                                                  -258.1437    232.833     -1.109      0.268    -715.416     199.128
#  Område_BBU AF Økonomi og Digitalisering                                                                                280.8720    405.984      0.692      0.489    -516.458    1078.202
#  Område_BBU Amager                                                                                                       95.2658     76.251      1.249      0.212     -54.487     245.019
#  Område_BBU Brønshøj-Husum-Vanløse                                                                                       54.3141     81.287      0.668      0.504    -105.330     213.958
#  Område_BBU City-Østerbro                                                                                               -56.7699     88.033     -0.645      0.519    -229.662     116.122
#  Område_BBU Flygtningeindsats                                                                                           -48.5118    203.320     -0.239      0.811    -447.821     350.797
#  Område_BBU Nørrebro-Bispebjerg                                                                                           8.6806     74.613      0.116      0.907    -137.855     155.216
#  Område_BBU Valby-Vesterbro-Kgs.Enghave                                                                                 -12.5351     77.089     -0.163      0.871    -163.935     138.864
#  Område_BCH Børneområdet                                                                                               -174.2412    111.864     -1.558      0.120    -393.936      45.453
#  Område_Teamet for koordineret indsats (KIT)                                                                            451.5774    403.900      1.118      0.264    -341.660    1244.815
#  ==============================================================================
#  Omnibus:                      183.690   Durbin-Watson:                   1.679
#  Prob(Omnibus):                  0.000   Jarque-Bera (JB):              639.947
#  Skew:                           1.303   Prob(JB):                    1.09e-139
#  Kurtosis:                       7.100   Cond. No.                     2.11e+17
#  ==============================================================================
#
#  Notes:
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#  [2] The smallest eigenvalue is 2.79e-22. This might indicate that there are
#  strong multicollinearity problems or that the design matrix is singular.
#  """}
